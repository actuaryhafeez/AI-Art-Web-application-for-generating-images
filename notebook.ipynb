# %% [markdown]
# # Import Libraries

# %%
import openai
import urllib.request
from PIL import Image
import requests
from io import BytesIO
import matplotlib.pyplot as plt

# %% [markdown]
# # Set OpenAI API Key

# %%
openai.api_key = "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"

# %% [markdown]
# # Generate Image

# %%
img_response = openai.Image.create(
    prompt = 'an astronaut lounging in a tropical resort in space',
    n=1,
    size="512x512")    # 256x256, 512x512, 1024x1024

# %% [markdown]
# # Get image URL from API response

# %%
img_url = img_response['data'][0]['url']

# %% [markdown]
# # Retrieve image from URL using requests library

# %%
response = requests.get(img_url)
img = Image.open(BytesIO(response.content))

# %% [markdown]
# # Display image using matplotlib

# %%
plt.imshow(img)
plt.axis('off')
plt.show()
